# %%
from safetensors.torch import load_file

# %%
checkpoint_sam_safetensor = '/mnt/workspace/models/facebook/sam-vit-base/model.safetensors'

# %%
state_dict_sam_safetensor = load_file(checkpoint_sam_safetensor)

# %%
for k in sorted(state_dict_sam_safetensor.keys()):
    print(k)
# Out:
# mask_decoder.iou_prediction_head.layers.0.bias
# mask_decoder.iou_prediction_head.layers.0.weight
# mask_decoder.iou_prediction_head.proj_in.bias
# mask_decoder.iou_prediction_head.proj_in.weight
# mask_decoder.iou_prediction_head.proj_out.bias
# mask_decoder.iou_prediction_head.proj_out.weight
# mask_decoder.iou_token.weight
# mask_decoder.mask_tokens.weight
# mask_decoder.output_hypernetworks_mlps.0.layers.0.bias
# mask_decoder.output_hypernetworks_mlps.0.layers.0.weight
# mask_decoder.output_hypernetworks_mlps.0.proj_in.bias
# mask_decoder.output_hypernetworks_mlps.0.proj_in.weight
# mask_decoder.output_hypernetworks_mlps.0.proj_out.bias
# mask_decoder.output_hypernetworks_mlps.0.proj_out.weight
# mask_decoder.output_hypernetworks_mlps.1.layers.0.bias
# mask_decoder.output_hypernetworks_mlps.1.layers.0.weight
# mask_decoder.output_hypernetworks_mlps.1.proj_in.bias
# mask_decoder.output_hypernetworks_mlps.1.proj_in.weight
# mask_decoder.output_hypernetworks_mlps.1.proj_out.bias
# ...
