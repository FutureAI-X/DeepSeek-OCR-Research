# %%
from deepencoder_clip import build_clip_l

# %%
vision_model = build_clip_l()

# %%
for k in sorted(vision_model.state_dict().keys()):
    print(k)
# Out:
# embeddings.class_embedding
# embeddings.patch_embedding.weight
# embeddings.position_embedding.weight
# embeddings.position_ids
# pre_layrnorm.bias
# pre_layrnorm.weight
# transformer.layers.0.layer_norm1.bias
# transformer.layers.0.layer_norm1.weight
# transformer.layers.0.layer_norm2.bias
# transformer.layers.0.layer_norm2.weight
# transformer.layers.0.mlp.fc1.bias
# transformer.layers.0.mlp.fc1.weight
# transformer.layers.0.mlp.fc2.bias
# transformer.layers.0.mlp.fc2.weight
# transformer.layers.0.self_attn.out_proj.bias
# transformer.layers.0.self_attn.out_proj.weight
# transformer.layers.0.self_attn.qkv_proj.bias
# transformer.layers.0.self_attn.qkv_proj.weight
# transformer.layers.1.layer_norm1.bias
# transformer.layers.1.layer_norm1.weight
# transformer.layers.1.layer_norm2.bias
# transformer.layers.1.layer_norm2.weight
# transformer.layers.1.mlp.fc1.bias
# transformer.layers.1.mlp.fc1.weight
# transformer.layers.1.mlp.fc2.bias
# transformer.layers.1.mlp.fc2.weight
# ...
